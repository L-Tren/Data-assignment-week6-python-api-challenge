# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 580

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid="+weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rapid valley
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | whitehorse
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | vorkuta
# Processing Record 9 of Set 1 | iskateley
# Processing Record 10 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 11 of Set 1 | zhumysker
# Processing Record 12 of Set 1 | puerto natales
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | shache
# Processing Record 15 of Set 1 | enewetak
# Processing Record 16 of Set 1 | tura
# Processing Record 17 of Set 1 | gwanda
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | griffith
# Processing Record 21 of Set 1 | kem'
# Processing Record 22 of Set 1 | adrar
# Processing Record 23 of Set 1 | waddan
# Processing Record 24 of Set 1 | ola
# Processing Record 25 of Set 1 | port lincoln
# Processing Record 26 of Set 1 | coahuayana de hidalgo
# Processing Record 27 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 28 of Set 1 | constantia
# Processing Record 29 of Set 1 | hawaiian paradise park
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | crane
# Processing Record 32 of Set 1 | kirakira
# Processing Record 33 of Set 1 | dwarka
# Processing Record 34 of Set 1 | atafu village
# Processing Record 35 of Set 1 | adamstown
# Processing Record 36 of Set 1 | west island
# Processing Record 37 of Set 1 | flying fish cove
# Processing Record 38 of Set 1 | sandnessjoen
# Processing Record 39 of Set 1 | pandan
# Processing Record 40 of Set 1 | isafjordur
# Processing Record 41 of Set 1 | tindouf
# Processing Record 42 of Set 1 | la'ie
# Processing Record 43 of Set 1 | baruun-urt
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | chibougamau
# Processing Record 46 of Set 1 | neyshabur
# Processing Record 47 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 48 of Set 1 | okhotsk
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | solnechnyy
# Processing Record 0 of Set 2 | college
# Processing Record 1 of Set 2 | blackmans bay
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | antofagasta
# Processing Record 4 of Set 2 | parobe
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | kargasok
# Processing Record 10 of Set 2 | olonkinbyen
# Processing Record 11 of Set 2 | waitangi
# Processing Record 12 of Set 2 | qaqortoq
# Processing Record 13 of Set 2 | la ligua
# Processing Record 14 of Set 2 | nova sintra
# Processing Record 15 of Set 2 | lib
# Processing Record 16 of Set 2 | jati
# Processing Record 17 of Set 2 | vila franca do campo
# Processing Record 18 of Set 2 | vorgashor
# Processing Record 6 of Set 5 | gulf shores
# Processing Record 7 of Set 5 | fort bragg
# Processing Record 8 of Set 5 | bulalacao
# Processing Record 9 of Set 5 | black point
# Processing Record 10 of Set 5 | holualoa
# Processing Record 11 of Set 5 | qamdo
# Processing Record 12 of Set 5 | oroqen zizhiqi
# Processing Record 13 of Set 5 | saint-affrique
# Processing Record 14 of Set 5 | puerto ayacucho
# Processing Record 15 of Set 5 | cocachacra
# Processing Record 16 of Set 5 | port blair
# Processing Record 17 of Set 5 | tateyama
# Processing Record 18 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 19 of Set 5 | am djarass
# City not found. Skipping...
# Processing Record 20 of Set 5 | gadzhiyevo
# Processing Record 21 of Set 5 | mugia
# Processing Record 22 of Set 5 | isangel
# Processing Record 23 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 24 of Set 5 | ta`u
# Processing Record 25 of Set 5 | cerveny kostelec
# Processing Record 26 of Set 5 | passau
# Processing Record 27 of Set 5 | nantucket
# Processing Record 28 of Set 5 | conceicao do araguaia
# Processing Record 29 of Set 5 | fale old settlement
# Processing Record 30 of Set 5 | kingston
# Processing Record 31 of Set 5 | gounou gaya
# Processing Record 32 of Set 5 | palikir - national government center
# Processing Record 33 of Set 5 | yuzhno-kurilsk
# Processing Record 34 of Set 5 | uturoa
# Processing Record 35 of Set 5 | salekhard
# Processing Record 36 of Set 5 | sofifi
# City not found. Skipping...
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | fomboni
# Processing Record 39 of Set 5 | cassino
# Processing Record 40 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 41 of Set 5 | saksaul'skiy
# City not found. Skipping...
# Processing Record 42 of Set 5 | mhamid
# Processing Record 43 of Set 5 | las vegas
# Processing Record 44 of Set 5 | auki
# Processing Record 45 of Set 5 | palmer
# Processing Record 46 of Set 5 | dudinka
# Processing Record 47 of Set 5 | maymana
# Processing Record 48 of Set 5 | mananjary
# Processing Record 49 of Set 5 | mount pearl
# Processing Record 0 of Set 6 | quellon
# Processing Record 1 of Set 6 | dhromolaxia
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | harnosand
# Processing Record 4 of Set 6 | kavaratti
# Processing Record 5 of Set 6 | manakara
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | fortuna
# Processing Record 8 of Set 6 | lodwar
# Processing Record 9 of Set 6 | siwa oasis
# Processing Record 10 of Set 6 | vikulovo
# Processing Record 11 of Set 6 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 12 of Set 6 | liepaja
# Processing Record 13 of Set 6 | aitape
# Processing Record 14 of Set 6 | vilyuysk
# Processing Record 15 of Set 6 | rio preto da eva
# Processing Record 16 of Set 6 | magong
# Processing Record 17 of Set 6 | bazarnyy syzgan
# Processing Record 18 of Set 6 | san ignacio
# Processing Record 19 of Set 6 | kourou
# Processing Record 20 of Set 6 | deqen
# Processing Record 21 of Set 6 | kiruna
# Processing Record 22 of Set 6 | ulanhot
# Processing Record 23 of Set 6 | okha
# Processing Record 24 of Set 6 | pueblo nuevo
# Processing Record 25 of Set 6 | viedma
# Processing Record 26 of Set 6 | raja
# Processing Record 27 of Set 6 | tan-tan
# Processing Record 28 of Set 6 | wotje
# Processing Record 29 of Set 6 | stanthorpe
# Processing Record 30 of Set 6 | bulgan
# Processing Record 31 of Set 6 | cabo san lucas
# Processing Record 32 of Set 6 | bereznik
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | mascoutah
# Processing Record 35 of Set 6 | gwio kura
# Processing Record 36 of Set 6 | carnarvon
# Processing Record 37 of Set 6 | port glaud
# City not found. Skipping...
# Processing Record 38 of Set 6 | benguela
# Processing Record 39 of Set 6 | egilsstadir
# Processing Record 40 of Set 6 | turinskaya sloboda
# Processing Record 41 of Set 6 | rajpur
# Processing Record 42 of Set 6 | mejit
# Processing Record 43 of Set 6 | bandipura
# Processing Record 44 of Set 6 | mossoro
# Processing Record 45 of Set 6 | callao
# Processing Record 46 of Set 6 | oriximina
# Processing Record 47 of Set 6 | nemuro
# Processing Record 48 of Set 6 | chonchi
# Processing Record 49 of Set 6 | inhambane
# Processing Record 0 of Set 7 | nar'yan-mar
# Processing Record 1 of Set 7 | tobol'sk
# Processing Record 2 of Set 7 | burang
# Processing Record 3 of Set 7 | la punta
# Processing Record 4 of Set 7 | pemangkat
# Processing Record 5 of Set 7 | barcelos
# Processing Record 6 of Set 7 | saint-pierre
# Processing Record 7 of Set 7 | krasnovishersk
# Processing Record 8 of Set 7 | hadibu
# Processing Record 9 of Set 7 | winburg
# Processing Record 10 of Set 7 | fort st. john
# Processing Record 11 of Set 7 | tokar
# Processing Record 12 of Set 7 | trogir
# Processing Record 13 of Set 7 | xiangtan
# Processing Record 14 of Set 7 | lawrenceville
# Processing Record 15 of Set 7 | turkmenbasy
# Processing Record 16 of Set 7 | charcas
# Processing Record 17 of Set 7 | arawa
# Processing Record 18 of Set 7 | pisco
# Processing Record 19 of Set 7 | gillette
# Processing Record 20 of Set 7 | roma
# Processing Record 21 of Set 7 | ejido benito juarez
# City not found. Skipping...
# Processing Record 22 of Set 7 | ubari
# Processing Record 23 of Set 7 | nouadhibou
# Processing Record 24 of Set 7 | dampit
# Processing Record 25 of Set 7 | ha'il
# Processing Record 26 of Set 7 | la souterraine
# Processing Record 27 of Set 7 | yeppoon
# Processing Record 28 of Set 7 | capim grosso
# Processing Record 29 of Set 7 | tubarjal
# Processing Record 30 of Set 7 | cooper's town
# Processing Record 31 of Set 7 | el fasher
# Processing Record 32 of Set 7 | kuanda
# Processing Record 33 of Set 7 | serhiyivka
# Processing Record 34 of Set 7 | las tablas
# Processing Record 35 of Set 7 | venado
# Processing Record 36 of Set 7 | krasnokamsk
# Processing Record 37 of Set 7 | lihue
# Processing Record 38 of Set 7 | antalaha
# Processing Record 7 of Set 9 | xiangxiang
# Processing Record 8 of Set 9 | saint-philippe
# Processing Record 9 of Set 9 | deir ez-zor
# Processing Record 10 of Set 9 | watsa
# Processing Record 11 of Set 9 | akureyri
# Processing Record 12 of Set 9 | ulladulla
# Processing Record 13 of Set 9 | san pedro
# Processing Record 14 of Set 9 | kralendijk
# Processing Record 15 of Set 9 | milton-freewater
# Processing Record 16 of Set 9 | san juan de miraflores
# Processing Record 17 of Set 9 | gebeit
# Processing Record 18 of Set 9 | nadi
# Processing Record 19 of Set 9 | voinjama
# Processing Record 20 of Set 9 | novozybkov
# Processing Record 21 of Set 9 | magadan
# Processing Record 22 of Set 9 | arno
# Processing Record 23 of Set 9 | shirvan
# Processing Record 24 of Set 9 | las heras
# Processing Record 25 of Set 9 | inongo
# Processing Record 26 of Set 9 | acarau
# Processing Record 27 of Set 9 | severo-yeniseyskiy
# Processing Record 28 of Set 9 | aral
# Processing Record 29 of Set 9 | sengkang
# Processing Record 30 of Set 9 | mandalgarh
# Processing Record 31 of Set 9 | segezha
# Processing Record 32 of Set 9 | teplice
# Processing Record 33 of Set 9 | usinsk
# Processing Record 34 of Set 9 | tanout
# Processing Record 35 of Set 9 | plastun
# Processing Record 36 of Set 9 | gueltat zemmour
# City not found. Skipping...
# Processing Record 37 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 38 of Set 9 | hasaki
# Processing Record 39 of Set 9 | ugoofaaru
# Processing Record 40 of Set 9 | bokani
# Processing Record 41 of Set 9 | coquimbo
# Processing Record 42 of Set 9 | sao joao da barra
# Processing Record 43 of Set 9 | arteche
# Processing Record 44 of Set 9 | villa yapacani
# Processing Record 45 of Set 9 | clovis
# Processing Record 46 of Set 9 | linxia chengguanzhen
# Processing Record 47 of Set 9 | rouissat
# Processing Record 48 of Set 9 | ust'-ilimsk
# Processing Record 49 of Set 9 | kigali
# Processing Record 0 of Set 10 | olyokminsk
# Processing Record 1 of Set 10 | port moresby
# Processing Record 2 of Set 10 | benghazi
# Processing Record 3 of Set 10 | caleta de carquin
# Processing Record 4 of Set 10 | tansen
# Processing Record 5 of Set 10 | mazagao
# Processing Record 6 of Set 10 | sao felix do xingu
# Processing Record 7 of Set 10 | bulungu
# Processing Record 8 of Set 10 | thunder bay
# Processing Record 9 of Set 10 | bel ombre
# Processing Record 10 of Set 10 | barra de santo antonio
# Processing Record 11 of Set 10 | alice springs
# Processing Record 12 of Set 10 | st. john's
# Processing Record 13 of Set 10 | sosnovo-ozerskoye
# Processing Record 14 of Set 10 | ambodifotatra
# Processing Record 15 of Set 10 | kapa'a
# Processing Record 16 of Set 10 | putla villa de guerrero
# Processing Record 17 of Set 10 | camamu
# Processing Record 18 of Set 10 | boa vista
# Processing Record 19 of Set 10 | yoko
# Processing Record 20 of Set 10 | tsiombe
# Processing Record 21 of Set 10 | nanao
# Processing Record 22 of Set 10 | pacific grove
# Processing Record 23 of Set 10 | touros
# Processing Record 24 of Set 10 | south mackay
# Processing Record 25 of Set 10 | boguchany
# Processing Record 26 of Set 10 | ganye
# Processing Record 27 of Set 10 | vila velha
# Processing Record 28 of Set 10 | anapa
# Processing Record 29 of Set 10 | avanhard
# Processing Record 30 of Set 10 | rio branco
# Processing Record 31 of Set 10 | itoman
# Processing Record 32 of Set 10 | masterton
# Processing Record 33 of Set 10 | leava
# Processing Record 34 of Set 10 | vernon
# Processing Record 35 of Set 10 | youghal
# Processing Record 36 of Set 10 | bani suhayla
# Processing Record 37 of Set 10 | north elba
# Processing Record 38 of Set 10 | gerze
# Processing Record 39 of Set 10 | shahba
# Processing Record 40 of Set 10 | zaragoza
# Processing Record 41 of Set 10 | san antonio de pale
# Processing Record 42 of Set 10 | kovernino
# Processing Record 43 of Set 10 | sheridan
# Processing Record 44 of Set 10 | tabou
# Processing Record 45 of Set 10 | hanzhong
# Processing Record 46 of Set 10 | madimba
# Processing Record 47 of Set 10 | watseka
# Processing Record 48 of Set 10 | great falls
# Processing Record 49 of Set 10 | keflavik
# Processing Record 0 of Set 11 | nova vicosa
# Processing Record 1 of Set 11 | chinde
# Processing Record 2 of Set 11 | tozkhurmato
# Processing Record 3 of Set 11 | ghadamis
# Processing Record 4 of Set 11 | moapa valley
# Processing Record 5 of Set 11 | suai
# City not found. Skipping...
# Processing Record 6 of Set 11 | puerto lempira
# Processing Record 7 of Set 11 | san
# Processing Record 8 of Set 11 | conception bay south
# Processing Record 9 of Set 11 | basse-terre
# Processing Record 10 of Set 11 | tvoroyri
# Processing Record 11 of Set 11 | port augusta
# Processing Record 12 of Set 11 | trongsa
# Processing Record 13 of Set 11 | hincesti
# Processing Record 14 of Set 11 | copiapo
# Processing Record 15 of Set 11 | kasongo-lunda
# Processing Record 16 of Set 11 | medicine hat
# Processing Record 17 of Set 11 | san borja
# Processing Record 18 of Set 11 | lesnoy
# Processing Record 19 of Set 11 | beau vallon
# Processing Record 20 of Set 11 | malalag
# Processing Record 21 of Set 11 | lexington
# Processing Record 22 of Set 11 | toliara
# Processing Record 23 of Set 11 | longquan
# Processing Record 24 of Set 11 | ad dilam
# Processing Record 25 of Set 11 | cannonvale
# Processing Record 26 of Set 11 | siocon
# Processing Record 27 of Set 11 | rabaul
# Processing Record 28 of Set 11 | nuuk
# Processing Record 29 of Set 11 | kanniyakumari
# Processing Record 30 of Set 11 | ancud
# Processing Record 31 of Set 11 | hilo
# Processing Record 32 of Set 11 | golyshmanovo
# Processing Record 33 of Set 11 | ngambe
# Processing Record 34 of Set 11 | san pedro pochutla
# Processing Record 35 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 36 of Set 11 | mili
# Processing Record 37 of Set 11 | kupang
# Processing Record 38 of Set 11 | aswan
# Processing Record 39 of Set 11 | sur
# Processing Record 40 of Set 11 | tuban
# Processing Record 41 of Set 11 | fort saskatchewan
# Processing Record 42 of Set 11 | leulumoega
# Processing Record 43 of Set 11 | fratautii noi
# Processing Record 44 of Set 11 | licheng
# Processing Record 45 of Set 11 | novi pazar
# Processing Record 46 of Set 11 | suntar
# Processing Record 47 of Set 11 | rundu
# Processing Record 48 of Set 11 | choibalsan
# Processing Record 49 of Set 11 | magdagachi
# Processing Record 0 of Set 12 | duncan town
# City not found. Skipping...
# Processing Record 1 of Set 12 | mkuranga
# Processing Record 2 of Set 12 | humaita
# Processing Record 3 of Set 12 | blairgowrie
# Processing Record 4 of Set 12 | san pedro de alcantara
# Processing Record 5 of Set 12 | puerto leguizamo
# Processing Record 6 of Set 12 | big spring
# Processing Record 7 of Set 12 | guantanamo
# Processing Record 8 of Set 12 | torres
# Processing Record 9 of Set 12 | murud
# Processing Record 10 of Set 12 | taroa
# Processing Record 11 of Set 12 | waingapu
# Processing Record 12 of Set 12 | pokhara
# Processing Record 13 of Set 12 | selfoss
# Processing Record 14 of Set 12 | robertsport
# Processing Record 15 of Set 12 | aur
# Processing Record 16 of Set 12 | corn island
# Processing Record 17 of Set 12 | tazacorte
# Processing Record 18 of Set 12 | road town
# Processing Record 19 of Set 12 | yongchuan
# Processing Record 20 of Set 12 | nombre de dios
# Processing Record 21 of Set 12 | antsiranana
# Processing Record 22 of Set 12 | joal-fadiout
# Processing Record 23 of Set 12 | borodulikha
# Processing Record 24 of Set 12 | kununurra
# Processing Record 25 of Set 12 | sagua la grande
# Processing Record 26 of Set 12 | strugi-krasnyye
# Processing Record 27 of Set 12 | ayaviri
# Processing Record 28 of Set 12 | panchgani
# Processing Record 29 of Set 12 | sao tome
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          555
# Lat           555
# Lng           555
# Max Temp      555
# Humidity      555
# Cloudiness    555
# Wind Speed    555
# Country       555
# Date          555
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    rapid valley  44.0625 -103.1463    -12.49        76           0
# 1       grytviken -54.2811  -36.5092      3.93        84          33
# 2  margaret river -33.9500  115.0667     22.45        66          45
# 3  ribeira grande  38.5167  -28.7000     17.22        88          20
# 4      whitehorse  60.7161 -135.0538    -15.55        93          65
#
#    Wind Speed Country        Date
# 0        0.89      US  1708164835
# 1        3.63      GS  1708164835
# 2        5.68      AU  1708164760
# 3        5.14      PT  1708164837
# 4        2.11      CA  1708164837

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          rapid valley  44.0625 -103.1463    -12.49        76           0
# 1             grytviken -54.2811  -36.5092      3.93        84          33
# 2        margaret river -33.9500  115.0667     22.45        66          45
# 3        ribeira grande  38.5167  -28.7000     17.22        88          20
# 4            whitehorse  60.7161 -135.0538    -15.55        93          65
#
#          Wind Speed Country        Date
# City_ID
# 0              0.89      US  1708164835
# 1              3.63      GS  1708164835
# 2              5.68      AU  1708164760
# 3              5.14      PT  1708164837
# 4              2.11      CA  1708164837

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x='Lat', y='Max Temp', grid=True)

# Incorporate the other graph properties
plt.xlabel('Latitude (degrees)')
plt.ylabel('Max Temperature (°C)')
plt.title('Latitude vs. Maximum Temperature')

# Save the figure
plt.savefig("output_data/ScatterPlot_Latitude_vs._Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. Humidity
city_data_df.plot.scatter(x='Lat', y='Humidity', grid=True)

# Incorporate the other graph properties
plt.xlabel('Latitude (degrees)')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs. Humidity')

# Save the figure
plt.savefig("output_data/ScatterPlot_Latitude_vs._Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. Cloudiness
city_data_df.plot.scatter(x='Lat', y='Cloudiness', grid=True)

# Incorporate the other graph properties
plt.xlabel('Latitude (degrees)')
plt.ylabel('Cloudiness (%)')
plt.title('Latitude vs. Cloudiness')

# Save the figure
plt.savefig("output_data/ScatterPlot_Latitude_vs.Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x='Lat', y='Wind Speed', grid=True)

# Incorporate the other graph properties
plt.xlabel('Latitude (degrees)')
plt.ylabel('Wind Speed (m/s)')
plt.title('Latitude vs. Wind Speed')

# Save the figure
plt.savefig("output_data/ScatterPlot_Latitude_vs.WindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.read_csv("output_data/cities.csv", index_col="Lat")
northern_hemi_df = northern_hemi_df[northern_hemi_df.index > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#          City_ID            City       Lng  Max Temp  Humidity  Cloudiness  \
# Lat
# 44.0625        0    rapid valley -103.1463    -12.49        76           0
# 38.5167        3  ribeira grande  -28.7000     17.22        88          20
# 60.7161        4      whitehorse -135.0538    -15.55        93          65
# 69.4865        6         talnakh   88.3972    -29.89        88          92
# 67.5000        7         vorkuta   64.0000    -24.14        91          60
#
#          Wind Speed Country        Date
# Lat
# 44.0625        0.89      US  1708164835
# 38.5167        5.14      PT  1708164837
# 60.7161        2.11      CA  1708164837
# 69.4865        2.83      RU  1708164838
# 67.5000        2.80      RU  1708164839

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.read_csv("output_data/cities.csv", index_col="Lat")
southern_hemi_df = southern_hemi_df[southern_hemi_df.index < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#           City_ID            City       Lng  Max Temp  Humidity  Cloudiness  \
# Lat
# -54.2811        1       grytviken  -36.5092      3.93        84          33
# -33.9500        2  margaret river  115.0667     22.45        66          45
# -0.7393         5    puerto ayora  -90.3518     25.99        89          70
# -51.7236       10  puerto natales  -72.4875      9.31        96          97
# -20.9333       15          gwanda   29.0000     36.98        18           3
#
#           Wind Speed Country        Date
# Lat
# -54.2811        3.63      GS  1708164835
# -33.9500        5.68      AU  1708164760
# -0.7393         3.23      EC  1708164838
# -51.7236        1.52      CL  1708164841
# -20.9333        3.53      ZW  1708164845

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Latitude and Max Temp x and y values
x_values_northern = northern_hemi_df.index
y_values_northern = northern_hemi_df['Max Temp']

# Linear regression calc for Southern Hemisphere
slope_northern, intercept_northern, r_value_northern, p_value_northern, std_err_northern = linregress(x_values_northern, y_values_northern)

# Scatter plot
plt.scatter(x_values_northern, y_values_northern, color='blue', label='Data')

# Plot regression line for Southern Hemisphere
plt.plot(x_values_northern, slope_northern * x_values_northern + intercept_northern, color='red', label='Linear Regression')

# Add chart features
plt.text(0.35, 0.05, f'Regression Line: y = {slope_northern:.2f} * x + {intercept_northern:.2f}\nR value: {r_value_northern:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Max Temp (°C)')
plt.title('Northern Hemisphere Latitude vs. Max Temp')

#Save
plt.savefig("output_data/Northern Hemisphere Latitude vs. Max Temp.png")

# Show plot
plt.show()

# %%
# Linear regression on Southern Hemisphere

# Latitude and Max Temp x and y values
x_values_southern = southern_hemi_df.index
y_values_southern = southern_hemi_df['Max Temp']

# Linear regression calc for Southern Hemisphere
slope_southern, intercept_southern, r_value_southern, p_value_southern, std_err_southern = linregress(x_values_southern, y_values_southern)

# Scatter plot
plt.scatter(x_values_southern, y_values_southern, color='blue', label='Data')

# Plot regression line for Southern Hemisphere
plt.plot(x_values_southern, slope_southern * x_values_southern + intercept_southern, color='red', label='Linear Regression')

# Add chart features
plt.text(0.35, 0.05, f'Regression Line: y = {slope_southern:.2f} * x + {intercept_southern:.2f}\nR value: {r_value_southern:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Max Temp (°C)')
plt.title('Southern Hemisphere Latitude vs. Max Temp')

#Save
plt.savefig("output_data/Southern Hemisphere Latitude vs. Max Temp.png")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Latitude and Humidity x and y values
x_values = northern_hemi_df.index
y_values = northern_hemi_df['Humidity']

# Linear regression calc
slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)

# Scatter plot
plt.scatter(x_values, y_values, color='blue', label='Data')

# Plot regression line
plt.plot(x_values, slope * x_values + intercept, color='red', label='Linear Regression')

# Add chart features
plt.text(1.1, 1.0, f'Regression Line: y = {slope:.2f} * x + {intercept:.2f}\nR value: {r_value:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere Latitude vs. Humidity')

#Save
plt.savefig("output_data/Northern Hemisphere Latitude vs. Humidity.png")

# Show plot
plt.show()

# %%
# Linear regression on Southern Hemisphere

# Latitude and Humidity x and y values
x_values_southern = southern_hemi_df.index
y_values_southern = southern_hemi_df['Humidity']

# Linear regression calc
slope_southern, intercept_southern, r_value_southern, p_value_southern, std_err_southern = linregress(x_values_southern, y_values_southern)

# Scatter plot
plt.scatter(x_values_southern, y_values_southern, color='blue', label='Data')

# Plot regression line
plt.plot(x_values_southern, slope_southern * x_values_southern + intercept_southern, color='red', label='Linear Regression')

# Add chart features
plt.text(1.1, 1.0, f'Regression Line: y = {slope_southern:.2f} * x + {intercept_southern:.2f}\nR value: {r_value_southern:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere Latitude vs. Humidity')

#Save
plt.savefig("output_data/Southern Hemisphere Latitude vs. Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Latitude and Cloudiness x and y values
x_values_northern = northern_hemi_df.index
y_values_northern = northern_hemi_df['Cloudiness']

# Linear regression calc
slope_northern, intercept_northern, r_value_northern, p_value_northern, std_err_northern = linregress(x_values_northern, y_values_northern)

# Scatter plot
plt.scatter(x_values_northern, y_values_northern, color='blue', label='Data')

# Plot regression line
plt.plot(x_values_northern, slope_northern * x_values_northern + intercept_northern, color='red', label='Linear Regression')

# Add chart features
plt.text(1.1, 1.0, f'Regression Line: y = {slope_northern:.2f} * x + {intercept_northern:.2f}\nR value: {r_value_northern:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='top', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere Latitude vs. Cloudiness')

#Save
plt.savefig("output_data/Northern Hemisphere Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %%
# Linear regression on Southern Hemisphere

# Latitude and Cloudiness x and y values
x_values_southern = southern_hemi_df.index
y_values_southern = southern_hemi_df['Cloudiness']

# Linear regression calc
slope_southern, intercept_southern, r_value_southern, p_value_southern, std_err_southern = linregress(x_values_southern, y_values_southern)

# Scatter plot
plt.scatter(x_values_southern, y_values_southern, color='blue', label='Data')

# Plot regression line
plt.plot(x_values_southern, slope_southern * x_values_southern + intercept_southern, color='red', label='Linear Regression')

# Add chart features
plt.text(0.075, 0.15, f'Regression Line: y = {slope_southern:.2f} * x + {intercept_southern:.2f}\nR value: {r_value_southern:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere Latitude vs. Cloudiness')

#Save
plt.savefig("output_data/Southern Hemisphere Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Latitude and Wind Speed x and y values
x_values_northern = northern_hemi_df.index
y_values_northern = northern_hemi_df['Wind Speed']

# Linear regression calc
slope_northern, intercept_northern, r_value_northern, p_value_northern, std_err_northern = linregress(x_values_northern, y_values_northern)

# Scatter plot
plt.scatter(x_values_northern, y_values_northern, color='blue', label='Data')

# Plot regression line
plt.plot(x_values_northern, slope_northern * x_values_northern + intercept_northern, color='red', label='Linear Regression')

# Add chart features
plt.text(0.05, 0.85, f'Regression Line: y = {slope_northern:.2f} * x + {intercept_northern:.2f}\nR value: {r_value_northern:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='top', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Wind Speed (m/s)')
plt.title('Northern Hemisphere Latitude vs. Wind Speed')

#Save
plt.savefig("output_data/Northern Hemisphere Latitude vs. Wind Speed.png")


# Show plot
plt.show()

# %%
# Linear regression on Southern Hemisphere

# Latitude and Wind Speed x and y values
x_values_southern = southern_hemi_df.index
y_values_southern = southern_hemi_df['Wind Speed']

# Linear regression calc
slope_southern, intercept_southern, r_value_southern, p_value_southern, std_err_southern = linregress(x_values_southern, y_values_southern)

# Scatter plot
plt.scatter(x_values_southern, y_values_southern, color='blue', label='Data')

# Plot regression line
plt.plot(x_values_southern, slope_southern * x_values_southern + intercept_southern, color='red', label='Linear Regression')

# Add chart features
plt.text(.1, .75, f'Regression Line: y = {slope_southern:.2f} * x + {intercept_southern:.2f}\nR value: {r_value_southern:.2f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='left')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Wind Speed (m/s)')
plt.title('Southern Hemisphere Latitude vs. Wind Speed')

#Save
plt.savefig("output_data/Southern Hemisphere Latitude vs. Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
