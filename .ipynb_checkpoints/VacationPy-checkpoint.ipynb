# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path
import matplotlib.pyplot as plt

# Import API key
from api_keys import geoapify_key

# Remove warnings
import warnings

warnings.filterwarnings("ignore")

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    rapid valley  44.0625 -103.1463    -12.49        76           0
# 1        1       grytviken -54.2811  -36.5092      3.93        84          33
# 2        2  margaret river -33.9500  115.0667     22.45        66          45
# 3        3  ribeira grande  38.5167  -28.7000     17.22        88          20
# 4        4      whitehorse  60.7161 -135.0538    -15.55        93          65
#
#    Wind Speed Country        Date
# 0        0.89      US  1708164835
# 1        3.63      GS  1708164835
# 2        5.68      AU  1708164760
# 3        5.14      PT  1708164837
# 4        2.11      CA  1708164837

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Humidity map
city_data_df.hvplot.points(x='Lng', y='Lat', size='Humidity', color='City', geo=True,
                            tiles='CartoLight', hover_cols=['City', 'Country', 'Humidity'], 
                            frame_width=700, frame_height=500,
                            title='Humidity in World Cities')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
min_temp_threshold = 21
max_temp_threshold = 33
humidity_threshold = 45

# Filter for ideal conditions
ideal_df = city_data_df[(city_data_df['Max Temp'] >= min_temp_threshold) & 
                        (city_data_df['Max Temp'] <= max_temp_threshold) & 
                        (city_data_df['Humidity'] < humidity_threshold)]

# Drop any rows with null values
ideal_df.dropna(inplace=True)

# Display results data
ideal_df.head()
# Out:
#     City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 5         5               pocone -16.2567  -56.6228     31.41        44
# 26       26          el porvenir  13.7617  -87.3458     28.63        36
# 34       34               babana  10.4295    3.8150     25.39        11
# 85       85  ingeniero jacobacci -41.3427  -69.5448     22.84        16
# 88       88          broken hill -31.9500  141.4333     29.81        22
#
#     Cloudiness  Wind Speed Country        Date
# 5           93        1.93      BR  1708128995
# 26           3        1.62      HN  1708129008
# 34          66        2.58      NG  1708129013
# 85           8       13.80      AR  1708129052
# 88           3        6.50      AU  1708129054

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# Create a copy of the DataFrame with selected columns
hotel_df = ideal_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 5                pocone      BR -16.2567  -56.6228        44
# 26          el porvenir      HN  13.7617  -87.3458        36
# 34               babana      NG  10.4295    3.8150        11
# 85  ingeniero jacobacci      AR -41.3427  -69.5448        16
# 88          broken hill      AU -31.9500  141.4333        22

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "limit": 20,
    "apiKey": geoapify_key,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    # params["filter"] = lat
    # params["bias"] = lng
    
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# pocone - nearest hotel: Andirah
# el porvenir - nearest hotel: No hotel found
# babana - nearest hotel: No hotel found
# ingeniero jacobacci - nearest hotel: Gran Hotel Argentino
# broken hill - nearest hotel: Ibis Styles
# leeton - nearest hotel: No hotel found
# gaoual - nearest hotel: Hotel
# douentza - nearest hotel: No hotel found
# kano - nearest hotel: Gab Hotel
# karwar - nearest hotel: Emerald Bay, Karwar, Sterling Holidays
# businga - nearest hotel: Hôtel Roho
# kidal - nearest hotel: No hotel found
# malvan - nearest hotel: Hotel Silver Sand
# adrar - nearest hotel: No hotel found
# sarmiento - nearest hotel: Ismar
# wankyi - nearest hotel: Pony Hotel
# seme - nearest hotel: No hotel found
# pusad - nearest hotel: No hotel found
# tidjikja - nearest hotel: No hotel found
# moyale - nearest hotel: Paul’s guest house
# stawell - nearest hotel: Coorrabin Motor Inn
# taoudenni - nearest hotel: No hotel found
# aleg - nearest hotel: Hotel Oasis Aleg
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Hotel map
hotel_df.hvplot.points(x='Lng', y='Lat', color='City', geo=True,
                            tiles='CartoLight', hover_cols=['City', 'Country', 'Hotel Name'], 
                            frame_width=700, frame_height=500,
                            title='Hotels In Ideal Weather Cities')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Country,Hotel Name)
